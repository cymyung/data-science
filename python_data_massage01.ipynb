# %% [markdown]
# <a href="https://colab.research.google.com/github/cymyung/data-science/blob/main/python_data_massage01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files

# %%
files.upload()

# %%
population = pd.read_excel('/content/population_seoul.xlsx',
                           header = 2,
                           usecols = 'B,D,G,J,N')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
population.head()
# Out:
#   동별(2)     소계.1     소계.2    소계.3     소계.5
# 0    소계  9659322  9414093  245229  1706138
# 1   종로구   151349   140397   10952    28383
# 2    중구   132054   121441   10613    25546
# 3   용산구   232069   217288   14781    39717
# 4   성동구   286564   279374    7190    48514

# %%
population.rename(columns = {population.columns[0] : '구별',
                             population.columns[1] : '인구수'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2a62291e43f2> in <cell line: 1>()
# ----> 1 population.rename(columns = {population.columns[0] : '구별',
#       2                              population.columns[1] : '인구수'})
#
# TypeError: 'str' object is not callable

# %%
type(population)
# Out:
# pandas.core.frame.DataFrame

# %%
population.columns
# Out:
# Index(['동별(2)', '소계.1', '소계.2', '소계.3', '소계.5'], dtype='object')

# %%
population.columns = ['a','b','c','d','e']

# %%
population
# Out:
#        a        b        c       d        e
# 0     소계  9659322  9414093  245229  1706138
# 1    종로구   151349   140397   10952    28383
# 2     중구   132054   121441   10613    25546
# 3    용산구   232069   217288   14781    39717
# 4    성동구   286564   279374    7190    48514
# 5    광진구   350820   336169   14651    55418
# 6   동대문구   355667   338115   17552    65657
# 7    중랑구   389316   384272    5044    76968
# 8    성북구   441065   429142   11923    78972
# 9    강북구   295773   291384    4389    67566
# 10   도봉구   311386   308986    2400    68682
# 11   노원구   504641   500104    4537    94102
# 12   은평구   467295   463298    3997    91395
# 13  서대문구   321726   308122   13604    57179
# 14   마포구   376285   365111   11174    56964
# 15   양천구   441517   438353    3164    74386
# 16   강서구   572382   566839    5543    99690
# 17   구로구   417774   394833   22941    78150
# 18   금천구   242567   229235   13332    44242
# 19  영등포구   398842   376139   22703    66362
# ...

# %%
population.columns[1] = '구별'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-53ffae953697> in <cell line: 1>()
# ----> 1 population.columns[1] = '구별'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5300     @final
#    5301     def __setitem__(self, key, value):
# -> 5302         raise TypeError("Index does not support mutable operations")
#    5303
#    5304     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
population.head()
# Out:
#      a        b        c       d        e
# 0   소계  9659322  9414093  245229  1706138
# 1  종로구   151349   140397   10952    28383
# 2   중구   132054   121441   10613    25546
# 3  용산구   232069   217288   14781    39717
# 4  성동구   286564   279374    7190    48514

# %%
population.rename(columns={population.columns[0]:'구별',
                           population.columns[1]:'인구수',
                           population.columns[2]:'한국인',
                           population.columns[3]:'외국인',
                           population.columns[4]:'고령자'},inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-6e3c5d00d6ba> in <cell line: 1>()
# ----> 1 population.rename(columns={population.columns[0]:'구별',
#       2                            population.columns[1]:'인구수',
#       3                            population.columns[2]:'한국인',
#       4                            population.columns[3]:'외국인',
#       5                            population.columns[4]:'고령자'},inplace = True)
#
# TypeError: 'str' object is not callable

# %%
population.head()
# Out:
#      a        b        c       d        e
# 0   소계  9659322  9414093  245229  1706138
# 1  종로구   151349   140397   10952    28383
# 2   중구   132054   121441   10613    25546
# 3  용산구   232069   217288   14781    39717
# 4  성동구   286564   279374    7190    48514

# %%
population.columns = ['구별','인구수','한국인','외국인','고령자']

# %%
population.head()
# Out:
#     구별      인구수      한국인     외국인      고령자
# 0   소계  9659322  9414093  245229  1706138
# 1  종로구   151349   140397   10952    28383
# 2   중구   132054   121441   10613    25546
# 3  용산구   232069   217288   14781    39717
# 4  성동구   286564   279374    7190    48514

# %%
cctv = pd.read_csv(files.upload())
# Out:
#      <input type="file" id="files-7c494281-184f-4489-a236-0c9a12a0cdb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c494281-184f-4489-a236-0c9a12a0cdb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cctv = pd.read_csv('/content/cctv_seoul.csv', encoding='euc-kr')

# %%
cctv.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-bc10c40e6c14> in <cell line: 1>()
# ----> 1 cctv.value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value'

# %%
cctv['2020년이전'] = cctv['2014년 이전']+cctv['2014년']+cctv['2015년'] +cctv['2016년']+cctv['2017년']+cctv['2018년']+cctv['2019년']+cctv['2020년']

# %%
cctv.head()
# Out:
#    Unnamed: 0   구분      총계 2014년 이전  2014년  2015년  2016년   2017년   2018년  \
# 0         NaN    계  92,991    5,896  3,927  6,416  8,812  11,598  10,887
# 1         1.0  종로구   1,966      553    103    160    130     144     150
# 2         2.0  중 구   2,584      217     77    236    240     372     386
# 3         3.0  용산구   2,970       87     68     83    295     491     115
# 4         4.0  성동구   4,175      157    110    366    281     942     457
#
#     2019년   2020년  2021년  2022년  2023년  \
# 0  13,083  11,803  9,396  9,302  1,871
# 1      67     233     88    207    131
# 2     155     361    403    137      0
# 3     322     623    422    464      0
# 4     643     485    367    232    135
#
#                                         2020년이전
# 0  5,8963,9276,4168,81211,59810,88713,08311,803
# 1                       55310316013014415067233
# 2                       21777236240372386155361
# 3                         876883295491115322623
# ...

# %%
 cctv.values
# Out:
# array([[nan, '계', '92,991', '5,896', '3,927', '6,416', '8,812', '11,598',
#         '10,887', '13,083', '11,803', '9,396', '9,302', '1,871',
#         '5,8963,9276,4168,81211,59810,88713,08311,803'],
#        [1.0, '종로구', '1,966', '553', '103', '160', '130', '144', '150',
#         '67', '233', '88', '207', '131', '55310316013014415067233'],
#        [2.0, '중 구', '2,584', '217', '77', '236', '240', '372', '386',
#         '155', '361', '403', '137', '0', '21777236240372386155361'],
#        [3.0, '용산구', '2,970', '87', '68', '83', '295', '491', '115',
#         '322', '623', '422', '464', '0', '876883295491115322623'],
#        [4.0, '성동구', '4,175', '157', '110', '366', '281', '942', '457',
#         '643', '485', '367', '232', '135', '157110366281942457643485'],
#        [5.0, '광진구', '3,592', '130', '176', '95', '40', '666', '460',
#         '712', '190', '738', '273', '112', '1301769540666460712190'],
#        [6.0, '동대문구', '2,759', '3', '5', '72', '774', '702', '201', '218',
# ...

# %%
cctv.head()
# Out:
#    Unnamed: 0   구분      총계 2014년 이전  2014년  2015년  2016년   2017년   2018년  \
# 0         NaN    계  92,991    5,896  3,927  6,416  8,812  11,598  10,887
# 1         1.0  종로구   1,966      553    103    160    130     144     150
# 2         2.0  중 구   2,584      217     77    236    240     372     386
# 3         3.0  용산구   2,970       87     68     83    295     491     115
# 4         4.0  성동구   4,175      157    110    366    281     942     457
#
#     2019년   2020년  2021년  2022년  2023년  \
# 0  13,083  11,803  9,396  9,302  1,871
# 1      67     233     88    207    131
# 2     155     361    403    137      0
# 3     322     623    422    464      0
# 4     643     485    367    232    135
#
#                                         2020년이전
# 0  5,8963,9276,4168,81211,59810,88713,08311,803
# 1                       55310316013014415067233
# 2                       21777236240372386155361
# 3                         876883295491115322623
# ...

# %%
type(cctv)
# Out:
# pandas.core.frame.DataFrame

# %%
cctv.fillna(0)
# Out:
#     Unnamed: 0    구분      총계 2014년 이전  2014년  2015년  2016년   2017년   2018년  \
# 0          0.0     계  92,991    5,896  3,927  6,416  8,812  11,598  10,887
# 1          1.0   종로구   1,966      553    103    160    130     144     150
# 2          2.0   중 구   2,584      217     77    236    240     372     386
# 3          3.0   용산구   2,970       87     68     83    295     491     115
# 4          4.0   성동구   4,175      157    110    366    281     942     457
# 5          5.0   광진구   3,592      130    176     95     40     666     460
# 6          6.0  동대문구   2,759        3      5     72    774     702     201
# 7          7.0   중랑구   4,193      555    104    145    153     170     215
# 8          8.0   성북구   4,957      318    229    322    594     811     867
# 9          9.0   강북구   3,321       21     16     68    210       4     375
# 10        10.0   도봉구   2,385       98     54     27     91     116     183
# ...

# %%
cctv.head(3)
# Out:
#    Unnamed: 0   구분      총계 2014년 이전  2014년  2015년  2016년   2017년   2018년  \
# 0         NaN    계  92,991    5,896  3,927  6,416  8,812  11,598  10,887
# 1         1.0  종로구   1,966      553    103    160    130     144     150
# 2         2.0  중 구   2,584      217     77    236    240     372     386
#
#     2019년   2020년  2021년  2022년  2023년  \
# 0  13,083  11,803  9,396  9,302  1,871
# 1      67     233     88    207    131
# 2     155     361    403    137      0
#
#                                         2020년이전
# 0  5,8963,9276,4168,81211,59810,88713,08311,803
# 1                       55310316013014415067233
# 2                       21777236240372386155361

# %%
del(cctv('Unnamed:0',axis=1))
# Out:
#   File "<ipython-input-69-6ee2e1f969ce>", line 1
#     del(cctv('Unnamed:0',axis=1))
#         ^
# SyntaxError: cannot delete function call

# %%
cctv.drop("Unnamed:0",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-a4896c63c40b> in <cell line: 1>()
# ----> 1 cctv.drop("Unnamed:0",axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
cctv1=cctv.drop(cctv.columns[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-7fe04c0212b5> in <cell line: 1>()
# ----> 1 cctv1=cctv.drop(cctv.columns[0])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
cctv1 = cctv.drop(cctv.columns[0],axis=1)

# %%
cctv1.head()
# Out:
#     구분      총계 2014년 이전  2014년  2015년  2016년   2017년   2018년   2019년   2020년  \
# 0    계  92,991    5,896  3,927  6,416  8,812  11,598  10,887  13,083  11,803
# 1  종로구   1,966      553    103    160    130     144     150      67     233
# 2  중 구   2,584      217     77    236    240     372     386     155     361
# 3  용산구   2,970       87     68     83    295     491     115     322     623
# 4  성동구   4,175      157    110    366    281     942     457     643     485
#
#    2021년  2022년  2023년                                       2020년이전
# 0  9,396  9,302  1,871  5,8963,9276,4168,81211,59810,88713,08311,803
# 1     88    207    131                       55310316013014415067233
# 2    403    137      0                       21777236240372386155361
# 3    422    464      0                         876883295491115322623
# 4    367    232    135                      157110366281942457643485

# %%
type(cctv1)
# Out:
# pandas.core.frame.DataFrame

# %%
cctv1.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
cctv1.index = cctv1['구분']

# %%
cctv1.index
# Out:
# Index(['계', '종로구', '중 구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구',
#        '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='구분')

# %%
cctv1.head()
# Out:
#       구분      총계 2014년 이전  2014년  2015년  2016년   2017년   2018년   2019년  \
# 구분
# 계      계  92,991    5,896  3,927  6,416  8,812  11,598  10,887  13,083
# 종로구  종로구   1,966      553    103    160    130     144     150      67
# 중 구  중 구   2,584      217     77    236    240     372     386     155
# 용산구  용산구   2,970       87     68     83    295     491     115     322
# 성동구  성동구   4,175      157    110    366    281     942     457     643
#
#       2020년  2021년  2022년  2023년                                       2020년이전
# 구분
# 계    11,803  9,396  9,302  1,871  5,8963,9276,4168,81211,59810,88713,08311,803
# 종로구     233     88    207    131                       55310316013014415067233
# 중 구     361    403    137      0                       21777236240372386155361
# 용산구     623    422    464      0                         876883295491115322623
# 성동구     485    367    232    135                      157110366281942457643485

# %%
cctv2=cctv1.drop(cctv1.columns["구분"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-e898bf154342> in <cell line: 1>()
# ----> 1 cctv2=cctv1.drop(cctv1.columns["구분"],axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5337                 key = np.asarray(key, dtype=bool)
#    5338
# -> 5339         result = getitem(key)
#    5340         # Because we ruled out integer above, we always get an arraylike here
#    5341         if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
cctv2 = cctv1.drop(cctv1.columns[0],axis=1)

# %%
cctv2
# Out:
#           총계 2014년 이전  2014년  2015년  2016년   2017년   2018년   2019년   2020년  \
# 구분
# 계     92,991    5,896  3,927  6,416  8,812  11,598  10,887  13,083  11,803
# 종로구    1,966      553    103    160    130     144     150      67     233
# 중 구    2,584      217     77    236    240     372     386     155     361
# 용산구    2,970       87     68     83    295     491     115     322     623
# 성동구    4,175      157    110    366    281     942     457     643     485
# 광진구    3,592      130    176     95     40     666     460     712     190
# 동대문구   2,759        3      5     72    774     702     201     218     229
# 중랑구    4,193      555    104    145    153     170     215    1074     976
# 성북구    4,957      318    229    322    594     811     867     714     253
# 강북구    3,321       21     16     68    210       4     375     963     569
# 도봉구    2,385       98     54     27     91     116     183     195     179
# ...

# %%
cctv2.index, cctv2.columns
# Out:
# (Index(['계', '종로구', '중 구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#         '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구',
#         '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#        dtype='object', name='구분'),
#  Index(['총계', '2014년 이전', '2014년', '2015년', '2016년', '2017년', '2018년', '2019년',
#         '2020년', '2021년', '2022년', '2023년', '2020년이전'],
#        dtype='object'))

# %%
cctv2.values.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-70778428b130> in <cell line: 1>()
# ----> 1 cctv2.values.astype(int)
#
# ValueError: invalid literal for int() with base 10: '92,991'

# %%
cctv2.values.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-a7754d3f2a6e> in <cell line: 1>()
# ----> 1 cctv2.values.replace(',', '').astype(int)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'replace'

# %%
type(cctv2)
# Out:
# pandas.core.frame.DataFrame
