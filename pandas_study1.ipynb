# %% [markdown]
# <a href="https://colab.research.google.com/github/cymyung/data-science/blob/main/pandas_study1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
list_data = [1,2,3,4,5]
example_obj = pd.Series(data = list_data)
example_obj
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
list_name = ['a','b','c','d','e']
example_obj = pd.Series(data = list_data, index = list_name)
example_obj
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
type(example_obj)
# Out:
# pandas.core.series.Series

# %%
example_obj.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
example_obj.shape
# Out:
# (5,)

# %%
type(example_obj.values)
# Out:
# numpy.ndarray

# %%
dict_data = {"a":11, "b":22,"c":33,"d":44,"e":55}
example_obj2 = pd.Series(dict_data, dtype = np.float32, name = "example_data")

# %%
example_obj2
# Out:
# a    11.0
# b    22.0
# c    33.0
# d    44.0
# e    55.0
# Name: example_data, dtype: float32

# %%
example_obj2["c"]
# Out:
# 33.0

# %%
example_obj2>32
# Out:
# a    False
# b    False
# c     True
# d     True
# e     True
# Name: example_data, dtype: bool

# %%
example_obj2[example_obj2>32]
# Out:
# c    33.0
# d    44.0
# e    55.0
# Name: example_data, dtype: float32

# %%
example_obj2["a"] = 42
example_obj2
# Out:
# a    42.0
# b    22.0
# c    33.0
# d    44.0
# e    55.0
# Name: example_data, dtype: float32

# %%
example_obj2<43
# Out:
# a     True
# b     True
# c     True
# d    False
# e    False
# Name: example_data, dtype: bool

# %%
example_obj * 100
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %%
type(example_obj2)
# Out:
# pandas.core.series.Series

# %%
example_obj2
# Out:
# a    42.0
# b    22.0
# c    33.0
# d    44.0
# e    55.0
# Name: example_data, dtype: float32

# %%
type(example_obj2)
# Out:
# pandas.core.series.Series

# %%
type(example_obj2.to_dict)
# Out:
# method

# %%
example_obj2.to_dict()
# Out:
# {'a': 42.0, 'b': 22.0, 'c': 33.0, 'd': 44.0, 'e': 55.0}

# %%
example_obj2.name
# Out:
# 'example_data'

# %%
example_obj2
# Out:
# a    42.0
# b    22.0
# c    33.0
# d    44.0
# e    55.0
# Name: example_data, dtype: float32

# %%
example_obj2.name = 'number'
example_obj2.index.name = 'alphabet'

# %%
example_obj2
# Out:
# alphabet
# a    42.0
# b    22.0
# c    33.0
# d    44.0
# e    55.0
# Name: number, dtype: float32

# %%
example_obj2.columns[0] = "aaa"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-752405d96d4a> in <cell line: 1>()
# ----> 1 example_obj2.columns[0] = "aaa"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
raw_data = {'first name' : ['Jason','Molly','Tina','Jake','Amy'],
            'last name' : ['Miller','Jacobson','Ali','Milner','Cooze'],
            'age' : [42,52,36,24,73],
            'city' : ['San Francisco','Baltimore','Miami','Douglas','Boston']}
df = pd.DataFrame(raw_data)

# %%
df
# Out:
#   first name last name  age           city
# 0      Jason    Miller   42  San Francisco
# 1      Molly  Jacobson   52      Baltimore
# 2       Tina       Ali   36          Miami
# 3       Jake    Milner   24        Douglas
# 4        Amy     Cooze   73         Boston

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['first name', 'last name', 'age', 'city'], dtype='object')

# %%
pd.DataFrame(raw_data, columns = ['first name','age'])
# Out:
#   first name  age
# 0      Jason   42
# 1      Molly   52
# 2       Tina   36
# 3       Jake   24
# 4        Amy   73

# %%
df
# Out:
#   first name last name  age           city
# 0      Jason    Miller   42  San Francisco
# 1      Molly  Jacobson   52      Baltimore
# 2       Tina       Ali   36          Miami
# 3       Jake    Milner   24        Douglas
# 4        Amy     Cooze   73         Boston

# %%
df1 = pd.DataFrame(raw_data, columns = ['first name','last name','age','city','debt'])

# %%
df1
# Out:
#   first name last name  age           city debt
# 0      Jason    Miller   42  San Francisco  NaN
# 1      Molly  Jacobson   52      Baltimore  NaN
# 2       Tina       Ali   36          Miami  NaN
# 3       Jake    Milner   24        Douglas  NaN
# 4        Amy     Cooze   73         Boston  NaN

# %%
df.age
# Out:
# 0    42
# 1    52
# 2    36
# 3    24
# 4    73
# Name: age, dtype: int64

# %%
df.age<40
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: age, dtype: bool

# %%
df[df.age<40]
# Out:
#   first name last name  age     city
# 2       Tina       Ali   36    Miami
# 3       Jake    Milner   24  Douglas

# %%
df1
# Out:
#   first name last name  age           city debt
# 0      Jason    Miller   42  San Francisco  NaN
# 1      Molly  Jacobson   52      Baltimore  NaN
# 2       Tina       Ali   36          Miami  NaN
# 3       Jake    Milner   24        Douglas  NaN
# 4        Amy     Cooze   73         Boston  NaN

# %%
df1['age']
# Out:
# 0    42
# 1    52
# 2    36
# 3    24
# 4    73
# Name: age, dtype: int64

# %%
df1.iloc[2:]
# Out:
#   first name last name  age     city debt
# 2       Tina       Ali   36    Miami  NaN
# 3       Jake    Milner   24  Douglas  NaN
# 4        Amy     Cooze   73   Boston  NaN

# %%
s = pd.Series(np.nan, index = [49,48,35,64,75,1,2,3,5,4])
s
# Out:
# 49   NaN
# 48   NaN
# 35   NaN
# 64   NaN
# 75   NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 5    NaN
# 4    NaN
# dtype: float64

# %%
s.loc[:3]
# Out:
# 49   NaN
# 48   NaN
# 35   NaN
# 64   NaN
# 75   NaN
# 1    NaN
# 2    NaN
# 3    NaN
# dtype: float64

# %%
s.iloc[:3]
# Out:
# 49   NaN
# 48   NaN
# 35   NaN
# dtype: float64

# %%
df.age>33
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: age, dtype: bool

# %%
df1
# Out:
#   first name last name  age           city debt
# 0      Jason    Miller   42  San Francisco  NaN
# 1      Molly  Jacobson   52      Baltimore  NaN
# 2       Tina       Ali   36          Miami  NaN
# 3       Jake    Milner   24        Douglas  NaN
# 4        Amy     Cooze   73         Boston  NaN

# %%
df = df1

# %%
df
# Out:
#   first name last name  age           city debt
# 0      Jason    Miller   42  San Francisco  NaN
# 1      Molly  Jacobson   52      Baltimore  NaN
# 2       Tina       Ali   36          Miami  NaN
# 3       Jake    Milner   24        Douglas  NaN
# 4        Amy     Cooze   73         Boston  NaN

# %%
df.debt = df.age>37

# %%
df
# Out:
#   first name last name  age           city   debt
# 0      Jason    Miller   42  San Francisco   True
# 1      Molly  Jacobson   52      Baltimore   True
# 2       Tina       Ali   36          Miami  False
# 3       Jake    Milner   24        Douglas  False
# 4        Amy     Cooze   73         Boston   True

# %%
values = pd.Series(data = ['m','f','f'],index = [0,1,3])
values
# Out:
# 0    m
# 1    f
# 3    f
# dtype: object

# %%
df['sex'] = values

# %%
df
# Out:
#   first name last name  age           city   debt  sex
# 0      Jason    Miller   42  San Francisco   True    m
# 1      Molly  Jacobson   52      Baltimore   True    f
# 2       Tina       Ali   36          Miami  False  NaN
# 3       Jake    Milner   24        Douglas  False    f
# 4        Amy     Cooze   73         Boston   True  NaN

# %%
df.T
# Out:
#                         0          1      2        3       4
# first name          Jason      Molly   Tina     Jake     Amy
# last name          Miller   Jacobson    Ali   Milner   Cooze
# age                    42         52     36       24      73
# city        San Francisco  Baltimore  Miami  Douglas  Boston
# debt                 True       True  False    False    True
# sex                     m          f    NaN        f     NaN

# %%
df.Values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-5203716236c1> in <cell line: 1>()
# ----> 1 df.Values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Values'

# %%
df.values
# Out:
# array([['Jason', 'Miller', 42, 'San Francisco', True, 'm'],
#        ['Molly', 'Jacobson', 52, 'Baltimore', True, 'f'],
#        ['Tina', 'Ali', 36, 'Miami', False, nan],
#        ['Jake', 'Milner', 24, 'Douglas', False, 'f'],
#        ['Amy', 'Cooze', 73, 'Boston', True, nan]], dtype=object)
